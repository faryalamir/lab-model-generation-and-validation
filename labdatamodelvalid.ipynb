# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

generation0 = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis.csv')
generation0.shape
generation0.head()
# Out:
#    Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# 0     Basic   College           2/18/11         Employed      M  ...
# 1     Basic   College           1/18/11       Unemployed      F  ...
# 2     Basic  Bachelor           2/10/11         Employed      M  ...
# 3  Extended   College           1/11/11         Employed      M  ...
# 4   Premium  Bachelor           1/17/11    Medical Leave      F  ...
#
#    Number of Open Complaints Number of Policies     Policy Type        Policy  \
# ...

# %%
generation = generation0.copy()
generation = generation.drop('Unnamed: 0', axis=1)
generation.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  DK49336     Arizona              4809.216960       No     Basic   College
# 1  KX64629  California              2228.525238       No     Basic   College
# 2  LZ68649  Washington             14947.917300       No     Basic  Bachelor
# 3  XL78013      Oregon             22332.439460      Yes  Extended   College
# 4  QA50777      Oregon              9025.067525       No   Premium  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/18/11         Employed      M   48029  ...
# 1           1/18/11       Unemployed      F       0  ...
# 2           2/10/11         Employed      M   22139  ...
# 3           1/11/11         Employed      M   49078  ...
# 4           1/17/11    Medical Leave      F   23675  ...
#
#   Number of Open Complaints Number of Policies     Policy Type        Policy  \
# 0                       0.0                  9  Corporate Auto  Corporate L3
# ...

# %% [raw]
# 1. Select the columns which are correlated with total_claim_amount and don't suffer from multicollinearity (see the previous lab)

# %%
generation1=generation._get_numeric_data()
display(generation1)
# Out:
#        Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0                  4809.216960   48029                    61
# 1                  2228.525238       0                    64
# 2                 14947.917300   22139                   100
# 3                 22332.439460   49078                    97
# 4                  9025.067525   23675                   117
# ...                        ...     ...                   ...
# 10905             15563.369440       0                   253
# 10906              5259.444853   61146                    65
# 10907             23893.304100   39837                   201
# 10908             11971.977650   64195                   158
# 10909              6857.519928       0                   101
#
#        Months Since Last Claim  Months Since Policy Inception  \
# 0                          7.0                             52
# 1                          3.0                             26
# ...

# %%
sns.heatmap(generation1.iloc[:,1:].corr().round(2), annot=True);

# %% [raw]
# 2. Remove outliers

# %%
sns.scatterplot(data=generation1, x="Monthly Premium Auto", y="Total Claim Amount")
# Out:
# <Axes: xlabel='Monthly Premium Auto', ylabel='Total Claim Amount'>

# %%
sns.boxplot(data=generation1, x="Monthly Premium Auto")
# Out:
# <Axes: xlabel='Monthly Premium Auto'>

# %%
sns.boxplot(data=generation1, x="Total Claim Amount")
# Out:
# <Axes: xlabel='Total Claim Amount'>

# %% [raw]
# 3. X-y split. (define which column you want to predict, and which ones you will use to make the prediction)

# %%
generation.select_dtypes('object')
# Out:
#       Customer       State Response  Coverage Education Effective To Date  \
# 0      DK49336     Arizona       No     Basic   College           2/18/11
# 1      KX64629  California       No     Basic   College           1/18/11
# 2      LZ68649  Washington       No     Basic  Bachelor           2/10/11
# 3      XL78013      Oregon      Yes  Extended   College           1/11/11
# 4      QA50777      Oregon       No   Premium  Bachelor           1/17/11
# ...        ...         ...      ...       ...       ...               ...
# 10905  FE99816      Nevada       No   Premium  Bachelor           1/19/11
# 10906  KX53892      Oregon       No     Basic   College            1/6/11
# 10907  TL39050     Arizona       No  Extended  Bachelor            2/6/11
# 10908  WA60547  California       No   Premium   College           2/13/11
# 10909  IV32877         NaN      NaN     Basic  Bachelor            1/8/11
#
#       EmploymentStatus Gender Location Code Marital Status     Policy Type  \
# ...

# %%
sns.boxplot(data=generation, x="Response",y="Total Claim Amount" )
# Out:
# <Axes: xlabel='Response', ylabel='Total Claim Amount'>

# %%
sns.histplot(data=generation, hue="Response",x="Total Claim Amount" )
# Out:
# <Axes: xlabel='Total Claim Amount', ylabel='Count'>

# %%
y=generation1["Total Claim Amount"]
X=generation1[["Monthly Premium Auto"]]
# y=generation1.iloc[:,7]

# %% [raw]
# 4. Use the Train-test split to create the Train, and Test sets (make sure to set the random_state option to any integer number of your choice).

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.20, random_state=60)

# %% [raw]
# 5. Use the pd.DataFrame() function to create new Pandas DataFrames from the X_train, and X_test Numpy arrays obtained in the previous step (make sure to use the columns= option to set the columns names to X.columns).

# %%
X_train_df = pd.DataFrame(X_train, columns=X.columns, index=X_train.index)
X_test_df = pd.DataFrame(X_test, columns=X.columns, index=X_test.index)
display(X_train_df)
display(X_test_df)
# Out:
#        Monthly Premium Auto
# 9640                     62
# 1294                    116
# 2644                     61
# 10811                   102
# 9321                     99
# ...                     ...
# 10339                    76
# 6543                    108
# 1418                     65
# 3137                     72
# 2253                     63
#
# [8728 rows x 1 columns]
#       Monthly Premium Auto
# 3041                    62
# 9227                    86
# 1969                   117
# 312                    131
# 547                    119
# ...                    ...
# 2305                   109
# 8954                    71
# 8682                    70
# 1844                    63
# 2110                   111
#
# [2182 rows x 1 columns]

# %% [raw]
# 6. Split the X_train Pandas DataFrame into two: numerical, and categorical using df.select_dtypes().

# %%
X_train_num = X_train_df.select_dtypes(np.number)
X_test_num  = X_test_df.select_dtypes(np.number)

X_train_cat = X_train_df.select_dtypes('object')
X_test_cat  = X_test_df.select_dtypes('object')

X_train_cat_nominal = X_train_cat[[]]
X_test_cat_nominal  = X_test_cat[[]]

X_train_cat_ordinal = X_train_cat[[]]
X_test_cat_ordinal  = X_test_cat[[]]
# Out:
# Empty DataFrame
# Columns: []
# Index: [9640, 1294, 2644, 10811, 9321, 2845, 3943, 9715, 7892, 8619, 2024, 6752, 2383, 1368, 1896, 9550, 5663, 1305, 9156, 7131, 7381, 8120, 6235, 3639, 5853, 4200, 3290, 6858, 1984, 7513, 3345, 5402, 10027, 6612, 2399, 562, 6770, 9666, 2686, 4786, 7931, 7151, 1916, 3824, 5156, 4024, 9002, 3218, 877, 5351, 4428, 2005, 10706, 5387, 8886, 2250, 8539, 2395, 10607, 3595, 1737, 3248, 7734, 10281, 2902, 5029, 779, 4691, 2081, 3835, 8523, 2251, 9405, 6762, 3322, 5883, 10271, 6425, 6606, 385, 6189, 9100, 8968, 861, 10076, 6991, 10375, 9381, 2568, 10745, 1815, 5841, 10292, 1903, 10385, 496, 5986, 3235, 1211, 7049, ...]
#
# [8728 rows x 0 columns]

# %% [raw]
# 7. If you need to transform any column, Train your transformers and/or scalers all the numerical columns using the .fit() only in the Train set (only one transformer/scaler for all the columns, check here, and here using the .transform()

# %%
from sklearn.preprocessing import PowerTransformer

pt = PowerTransformer()
transformer = pt.fit(X_train_df)
X_train_transformed = pt.transform(X_train_df)
X_test_transformed = pt.transform(X_test_df)

# %% [raw]
# 8. Save all your transformers/scalers right after the .fit() using pickle using the code shown below:

# %%
import os

path = "./transformers/"
# Check whether the specified path exists or not
isExist = os.path.exists(path)
if not isExist:
    # Create a new directory because it does not exist
    os.makedirs(path)
    print("The new directory is created!")

filename = "transformer_x.pkl" # Use a descriptive name for your scaler/transformer but keep the ".pkl" file extension
with open(path+filename, "wb") as file:
  pickle.dump(transformer, file) # Replace "variable" with the name of the variable that contains your transformer

# %% [raw]
# 9. If you used a transformer/scaler in the previous step, create new Pandas DataFrames from the Numpy arrays generated by the .transform() using the pd.DataFrame() function as you did earlier with the Numpy arrays generated by the train_test_split() function.

# %%
X_train_transformed_df = pd.DataFrame(X_train_transformed, columns=X_train_num.columns)
X_test_transformed_df = pd.DataFrame(X_test_transformed, columns=X_train_num.columns)

# %% [raw]
# 10. Transform the categorical columns

# %%
from sklearn.preprocessing import OneHotEncoder

encoder = OneHotEncoder(drop='first', sparse=False)
categorical_column_fit = encoder.fit(categorical_column_train)
categorical_column_train_tf = encoder.transform(trained_column)
categorical_column_test_tf = encoder.transform(test_column)

path = "./encoders/"
# Check whether the specified path exists or not
isExist = os.path.exists(path)
if not isExist:
    # Create a new directory because it does not exist
    os.makedirs(path)
    print("The new directory is created!")

filename = "encoder.pkl"
with open(path+filename, "wb") as file:
    pickle.dump(categorical_column_fit, file)
# Out:
#        Monthly Premium Auto
# 9640                     62
# 1294                    116
# 2644                     61
# 10811                   102
# 9321                     99
# ...                     ...
# 10339                    76
# 6543                    108
# 1418                     65
# 3137                     72
# 2253                     63
#
# [8728 rows x 1 columns]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[68], line 5
#       3 encoder = OneHotEncoder(drop='first', sparse=False)
#       4 display(X_train)
# ----> 5 X_train_encoded = encoder.fit_transform(X_train[categorical_columns])
#       6 with open("encoders/encoder.pkl", "wb") as file:
#       7     pickle.dump(encoder, file)
#
# NameError: name 'categorical_columns' is not defined

# %% [raw]
# 11. Concat numerical_transformer and categorical_transfomed DataFrames using pd.concat().

# %%
# Assuming you have already transformed your numerical and categorical data
# X_train_num_transformed and X_test_num_transformed are the transformed numerical DataFrames
# X_train_cat_encoded and X_test_cat_encoded are the encoded categorical DataFrames

# Concatenate numerical and categorical DataFrames
X_train_final = pd.concat([X_train_transformed, X_train_cat_encoded], axis=1)
X_test_final = pd.concat([X_test_transformed, X_test_cat_encoded], axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[71], line 6
#       1 # Assuming you have already transformed your numerical and categorical data
#       2 # X_train_num_transformed and X_test_num_transformed are the transformed numerical DataFrames
#       3 # X_train_cat_encoded and X_test_cat_encoded are the encoded categorical DataFrames
#       4
#       5 # Concatenate numerical and categorical DataFrames
# ----> 6 X_train_final = pd.concat([X_train_transformed, X_train_cat_encoded], axis=1)
#       7 X_test_final = pd.concat([X_test_transformed, X_test_cat_encoded], axis=1)
#
# NameError: name 'X_train_cat_encoded' is not defined

# %% [raw]
# 12. Apply another MinMaxScaler to the concatenated DataFrame.
# 13. Remember to save all your MinMaxScaler right after the .fit() using pickle using the code shown below:

# %%
from sklearn.preprocessing import MinMaxScaler
import pickle
import os

# Initialize the MinMaxScaler
scaler = MinMaxScaler()

scaler_fit = scaler.fit(X_train_final)

# Fit and transform the scaler on the training data
X_train_final_scaled = scaler.transform(X_train_final)

# Transform the test data using the same scaler
X_test_final_scaled = scaler.transform(X_test_final)

# Save the scaler using pickle
path = "./scalers/"
# Check whether the specified path exists or not
isExist = os.path.exists(path)
if not isExist:
  # Create a new directory because it does not exist
  os.makedirs(path)
  print("The new directory is created!")

filename = "min_max_scaler.pkl" # use a descriptive name for your encoder but keep the ".pkl" file extension
with open(path+filename, "wb") as file:
   pickle.dump(scaler_fit, file) # Replace "variable" with the name of the variable that contains your transformer
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[83], line 8
#       5 # Initialize the MinMaxScaler
#       6 scaler = MinMaxScaler()
# ----> 8 scaler_fit = scaler.fit(X_train_final)
#      10 # Fit and transform the scaler on the training data
#      11 X_train_final_scaled = scaler.transform(X_train_final)
#
# NameError: name 'X_train_final' is not defined

# %% [raw]
# 14. Apply linear regression to the Pandas DataFrame obtained in the previous step using sklearn

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train_transformed_df, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 4
#       1 from sklearn.linear_model import LinearRegression
#       3 model = LinearRegression()
# ----> 4 model.fit(X_train_transformed_df, y_train)
#
# NameError: name 'X_train_transformed_df' is not defined

# %% [raw]
# 15. Remember to save your linear model right after the .fit() using pickle using the code shown below:

# %%
model = LinearRegression()
model_fit = model.fit(X_train, y_train)

path = "./models/"
# Check whether the specified path exists or not
isExist = os.path.exists(path)
if not isExist:
  # Create a new directory because it does not exist
    os.makedirs(path)
    print("The new directory is created!")

filename = "linear_regression_model.pkl" # use a descriptive name for your encoder but keep the ".pkl" file extension
with open(path+filename, "wb") as file:
    pickle.dump(model_fit, file) # Replace "variable" with the name of the variable that contains your transformer
# Out:
# The new directory is created!

# %% [raw]
# 16. Compute the following metrics for your Train and Test sets:
#
# R2.
# MSE.
# RMSE
# MAE.

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

y_train_pred = model.predict(X_train_transformed_df)
y_test_pred = model.predict(X_test_transformed_df)

train_r2 = r2_score(y_train, y_train_pred)
test_r2 = r2_score(y_test, y_test_pred)

train_mse = mean_squared_error(y_train, y_train_pred)
test_mse = mean_squared_error(y_test, y_test_pred)

train_rmse = np.sqrt(train_mse)
test_rmse = np.sqrt(test_mse)

train_mae = mean_absolute_error(y_train, y_train_pred)
test_mae = mean_absolute_error(y_test, y_test_pred)

# %% [raw]
# Create a Pandas DataFrame to summarize the error metrics for the Train and Test sets.

# %%
metrics_summary = pd.DataFrame({
    'Metric': ['R2', 'MSE', 'RMSE', 'MAE'],
    'Train Set': [train_r2, train_mse, train_rmse, train_mae],
    'Test Set': [test_r2, test_mse, test_rmse, test_mae]
})

display(metrics_summary)
# Out:
#   Metric      Train Set       Test Set
# 0     R2      -2.910402      -3.030599
# 1    MSE  336845.035571  331489.623648
# 2   RMSE     580.383525     575.751356
# 3    MAE     502.404331     500.856155
